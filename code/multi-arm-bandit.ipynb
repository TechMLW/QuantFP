# %% [markdown]
# # Classical Multi-Armed Bandit → Quantum Decision Model

# %%
# %pip install pennylane pennylane-lightning torch scikit-learn matplotlib
# Out:
# Requirement already satisfied: pennylane in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (0.43.2)
# Requirement already satisfied: pennylane-lightning in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (0.43.0)
# Requirement already satisfied: torch in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (2.9.1)
# Requirement already satisfied: scikit-learn in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (1.8.0)
# Requirement already satisfied: matplotlib in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (3.10.6)
# Requirement already satisfied: scipy in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from pennylane) (1.16.2)
# Requirement already satisfied: networkx in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from pennylane) (3.6.1)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from pennylane) (0.17.1)
# Requirement already satisfied: autograd in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from pennylane) (1.8.0)
# Requirement already satisfied: appdirs in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from pennylane) (1.4.4)
# Requirement already satisfied: autoray==0.8.0 in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from pennylane) (0.8.0)
# Requirement already satisfied: cachetools in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from pennylane) (6.2.4)
# Requirement already satisfied: requests in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from pennylane) (2.32.5)
# Requirement already satisfied: tomlkit in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from pennylane) (0.13.3)
# Requirement already satisfied: typing_extensions in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from pennylane) (4.15.0)
# Requirement already satisfied: packaging in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from pennylane) (25.0)
# Requirement already satisfied: diastatic-malt in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from pennylane) (2.15.2)
# Requirement already satisfied: numpy in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from pennylane) (2.3.3)
# Requirement already satisfied: scipy-openblas32>=0.3.26 in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from pennylane-lightning) (0.3.30.359.2)
# Requirement already satisfied: filelock in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from torch) (3.20.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: jinja2 in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from torch) (2025.12.0)
# Requirement already satisfied: setuptools in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: astunparse in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from diastatic-malt->pennylane) (1.6.3)
# Requirement already satisfied: gast in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from diastatic-malt->pennylane) (0.7.0)
# Requirement already satisfied: termcolor in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from diastatic-malt->pennylane) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from astunparse->diastatic-malt->pennylane) (0.45.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from requests->pennylane) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from requests->pennylane) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from requests->pennylane) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kiit0001\appdata\local\programs\python\python313\lib\site-packages (from requests->pennylane) (2025.8.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Cell 1 — Imports & Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import pennylane as qml

# %% [markdown]
# ### Cell 2 — Bandit Environment (Shared, Controlled)

# %%
N_ARMS = 3
TIME_STEPS = 300

# True reward probabilities (unknown to agents)
ARM_PROBS = [0.2, 0.5, 0.8]

def pull_arm(arm):
    return 1 if np.random.rand() < ARM_PROBS[arm] else 0

# %% [markdown]
# ### Cell 3 — Metrics Template (SVM-STYLE)

# %%
metrics_classical = {
    "progress": [],
    "performance": []
}

metrics_quantum = {
    "progress": [],
    "performance": []
}

# %% [markdown]
# ## CLASSICAL ε-GREEDY BANDIT

# %% [markdown]
# ### Cell 4 — Classical Agent Initialization

# %%
Q = np.zeros(N_ARMS)
epsilon = 0.1
alpha = 0.1

# %% [markdown]
# ### Cell 5 — Classical Training Loop (WITH METRICS)

# %%
cumulative_reward = 0

for t in range(TIME_STEPS):

    # ε-greedy action selection
    if np.random.rand() < epsilon:
        action = np.random.randint(N_ARMS)
    else:
        action = np.argmax(Q)

    reward = pull_arm(action)

    # Q-value update
    Q[action] += alpha * (reward - Q[action])

    cumulative_reward += reward

    # 🔴 METRIC COLLECTION (SVM-STYLE)
    metrics_classical["progress"].append(t)
    metrics_classical["performance"].append(cumulative_reward)

# %% [markdown]
# ## QUANTUM BANDIT (VARIATIONAL POLICY)

# %% [markdown]
# ### Cell 6 — Quantum Policy Circuit
#
# We model action preference using a variational quantum circuit.

# %%
N_QUBITS = 3
dev = qml.device("default.qubit", wires=N_QUBITS)

@qml.qnode(dev, interface="torch")
def quantum_policy(state, weights):
    qml.AngleEmbedding(state, wires=range(N_QUBITS))
    qml.BasicEntanglerLayers(weights, wires=range(N_QUBITS))
    return [qml.expval(qml.PauliZ(i)) for i in range(N_QUBITS)]

# %% [markdown]
# ### Cell 7 — Quantum Parameters & Optimizer

# %%
weights = torch.nn.Parameter(torch.randn(2, N_QUBITS))
optimizer = torch.optim.Adam([weights], lr=0.1)

# %% [markdown]
# ### Cell 8 — Quantum Training Loop (WITH METRICS)
#
# We treat the bandit as a stateless decision problem and learn a quantum policy that biases toward high-reward arms.

# %%
cumulative_reward = 0

for t in range(TIME_STEPS):

    # Dummy state (bandit has no true state)
    state = torch.rand(N_QUBITS)

    logits = torch.stack(quantum_policy(state, weights))
    probs = torch.softmax(logits, dim=0)

    action = torch.multinomial(probs, 1).item()
    reward = pull_arm(action)

    # Policy gradient–style update
    loss = -torch.log(probs[action]) * reward

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    cumulative_reward += reward

    # 🔴 METRIC COLLECTION (MATCHES CLASSICAL)
    metrics_quantum["progress"].append(t)
    metrics_quantum["performance"].append(cumulative_reward)

# %% [markdown]
# ### Cell 9 — Performance Comparison Plot

# %%
plt.figure(figsize=(8, 5))

plt.plot(
    metrics_classical["progress"],
    metrics_classical["performance"],
    label="Classical ε-Greedy Bandit"
)

plt.plot(
    metrics_quantum["progress"],
    metrics_quantum["performance"],
    label="Quantum Policy Bandit"
)

plt.xlabel("Time Step")
plt.ylabel("Cumulative Reward")
plt.title("Classical vs Quantum Multi-Armed Bandit Performance")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Cell 10 — Final Results Table

# %%
results = pd.DataFrame({
    "Model": ["Classical Bandit", "Quantum Bandit"],
    "Total Reward": [
        metrics_classical["performance"][-1],
        metrics_quantum["performance"][-1]
    ],
    "Average Reward per Step": [
        metrics_classical["performance"][-1] / TIME_STEPS,
        metrics_quantum["performance"][-1] / TIME_STEPS
    ]
})

results
# Out:
#               Model  Total Reward  Average Reward per Step
# 0  Classical Bandit           227                 0.756667
# 1    Quantum Bandit           208                 0.693333

# %% [markdown]
# **Paper framing:**
# “Quantum policies model strategic decisions via entangled action representations.”
